# %% [markdown]
# # Add 7 Collective Influence (CI) columns into the raw dataset

# %% [markdown]
# # Connect folders in Google Drive

# %%
# mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# change directory to PriceGraph folder
# %cd /content/drive/MyDrive/Swinburne/COS30018_IntelligentSystem/COS30018_GroupAssignment/SharedNotebooks/Thao/ProbabilisticDL/featured_engineering/PriceGraph/PriceGraphT10/PriceGraph
# Out:
# /content/drive/MyDrive/Swinburne/COS30018_IntelligentSystem/COS30018_GroupAssignment/SharedNotebooks/Thao/ProbabilisticDL/featured_engineering/PriceGraph/PriceGraphT10/PriceGraph

# %% [markdown]
# # Install Dependencies

# %%
import torch
print(torch. __version__)
# Out:
# 2.6.0+cu124

# %%
# !pip install networkx pyunicorn

# %% [markdown]
# # Data preparation

# %% [markdown]
# Move any **raw data file** into the `data` folder inside the `PriceGraph` folder with new name is "0.csv" file.

# %%
# change directory to code folder
# %cd code
# Out:
# /content/drive/MyDrive/Swinburne/COS30018_IntelligentSystem/COS30018_GroupAssignment/SharedNotebooks/Thao/ProbabilisticDL/featured_engineering/PriceGraph/PriceGraphT10/PriceGraph/code

# %% [markdown]
# ## Transform stock prices to graphs

# %%
# connect data in folder PriceGraph/data with the name of csv file is 0.csv

import pandas as pd

data = pd.read_csv('/content/drive/MyDrive/Swinburne/COS30018_IntelligentSystem/COS30018_GroupAssignment/SharedNotebooks/Thao/ProbabilisticDL/featured_engineering/PriceGraph/PriceGraphT10/PriceGraph/data/0.csv')
data
# Out:
#             Date       Close        High         Low        Open    Volume
# 0     2012-01-03   21.120089   21.269987   20.820288   20.946519  64731500
# 1     2012-01-04   21.617134   21.672360   21.127988   21.159545  80516100
# 2     2012-01-05   21.838041   21.877488   21.530353   21.601356  56081400
# 3     2012-01-06   22.177284   22.240400   21.719695   21.719695  99455500
# 4     2012-01-09   21.885370   22.169391   21.869591   22.129943  59706800
# ...          ...         ...         ...         ...         ...       ...
# 3252  2024-12-05  442.619995  444.660004  436.170013  437.920013  21697800
# 3253  2024-12-06  443.570007  446.100006  441.769989  442.299988  18821000
# 3254  2024-12-09  446.019989  448.329987  440.500000  442.600006  19144400
# 3255  2024-12-10  443.329987  449.619995  441.600006  444.390015  18469500
# 3256  2024-12-11  448.989990  450.350006  444.049988  444.049988  19200200
#
# [3257 rows x 6 columns]

# %%
# Transform stock prices to graphs
# !python price_graph.py
# Out:
# Streaming output truncated to the last 5000 lines.
# Calculating visibility relations...
# Calculating visibility relations...
# Calculating visibility relations...
# Calculating visibility relations...
# Calculating visibility relations...
# Calculating visibility relations...
# Calculating visibility relations...
# Calculating visibility relations...
# Calculating visibility relations...
# Calculating visibility relations...
# Calculating visibility relations...
# Calculating visibility relations...
# Calculating visibility relations...
# Calculating visibility relations...
# Calculating visibility relations...
# Calculating visibility relations...
# Calculating visibility relations...
# Calculating visibility relations...
# Calculating visibility relations...
# Calculating visibility relations...
# Calculating visibility relations...
# Calculating visibility relations...
# Calculating visibility relations...
# Calculating visibility relations...
# ...

# %% [markdown]
# ## Calculate collective influence (CI) for graph nodes

# %%
# Calculate collective influence (CI) for graph nodes
# !python price_ci.py

# %% [markdown]
# # Merge the raw dataset and the newly created 7 collective_influence columns dataset

# %% [markdown]
# Note:
# - data: raw data located in the `PriceGraph/data/0.csv`
# - close_ci: newly created ci file located in `PriceGraph/CI/Close/collective_influence.csv`

# %%
# Left join the initial Data file with the CI Close table file

import pandas as pd

data = pd.read_csv('/content/drive/MyDrive/Swinburne/COS30018_IntelligentSystem/COS30018_GroupAssignment/SharedNotebooks/Thao/ProbabilisticDL/featured_engineering/PriceGraph/PriceGraphT10/PriceGraph/data/0.csv')
close_ci = pd.read_csv('/content/drive/MyDrive/Swinburne/COS30018_IntelligentSystem/COS30018_GroupAssignment/SharedNotebooks/Thao/ProbabilisticDL/featured_engineering/PriceGraph/PriceGraphT10/PriceGraph/CI/Close/collective_influence.csv')

close_ci = close_ci.rename(columns={'day': 'Date', '1': 'ci1', '2': 'ci2', '3': 'ci3', '4': 'ci4', '5': 'ci5', '6': 'ci6', '7': 'ci7', '8': 'ci8', '9': 'ci9', '10': 'ci10'})

joined_data = data.merge(close_ci, on='Date', how='left')
joined_data.head(50)
# Out:
#           Date      Close       High        Low       Open     Volume   ci1  \
# 0   2012-01-03  21.120089  21.269987  20.820288  20.946519   64731500   NaN
# 1   2012-01-04  21.617134  21.672360  21.127988  21.159545   80516100   NaN
# 2   2012-01-05  21.838041  21.877488  21.530353  21.601356   56081400   NaN
# 3   2012-01-06  22.177284  22.240400  21.719695  21.719695   99455500   NaN
# 4   2012-01-09  21.885370  22.169391  21.869591  22.129943   59706800   NaN
# 5   2012-01-10  21.964264  22.208837  21.893259  22.035269   60014400   NaN
# 6   2012-01-11  21.869593  22.074719  21.593463  21.640799   65582400   0.0
# 7   2012-01-12  22.090500  22.106279  21.814368  21.987938   49370800   8.0
# 8   2012-01-13  22.287737  22.287737  21.924822  22.035274   60196100   0.0
# 9   2012-01-17  22.295622  22.603310  22.224617  22.406074   72395300   0.0
# 10  2012-01-18  22.271957  22.406078  22.066831  22.335073   64860600   4.0
# ...

# %%
# save the new joined_data into a csv file

data_path = '/content/drive/MyDrive/Swinburne/COS30018_IntelligentSystem/COS30018_GroupAssignment/SharedNotebooks/group2_code_submission/data/price_graph/'
new_file_name = 'ci_Microsoft_20120101_to_20241212.csv'

joined_data.to_csv(data_path + new_file_name, index=False)
